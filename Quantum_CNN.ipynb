# %% [markdown]
# ## Quantum Convolutional Neural Networks
#
# Here, we will implement a Quantum Convolutional Neural Network , a quantum machine learning model, introduced by [Henderson et al.](https://arxiv.org/abs/1904.04767)

# %% [markdown]
# #### Classical Convolution
#
# The convolutional neural network (CNN) is a standard model in classical machine learning which is particularly suitable for processing images. The model is based on the idea of a convolution layer where, instead of processing the full input data with a global function, a local convolution is applied.
#
# If the input is an image, small local regions are sequentially processed with the same kernel. The results obtained for each region are usually associated to different channels of a single output pixel. The union of all the output pixels produces a new image-like object, which can be further processed by additional layers

# %% [markdown]
# ### Quantum Convolution
#
# Same idea can be used in quantum variational circuits.
#
#
#
# 1.   A small region of the input image $2 \times 2$ square (in our examples) is embedded into a quantum circuit. We achieve this with the help of parameterized rotations applied to the qubits intialized in the ground state.
# 2.   A quantum computation, associated to a unitary $U$, is performed on the system. The unitary could be generated by a variational quantum circuit, or by a random circuit.
#
# 3. The quantum system is finally measured, obtaining a list of classical expectation values. The measurement results could also be classicaly post-processed.
#
# 4. Analogously to a classical convolutional layer, each expectation value is mapped to a different channel of a single output pixel
#
# 5. Iterating the same procedure over different regions, we can scan the entire image, producing an output object which will be structured as multi-channel image.
#
# 6. The quantum convolution can be followed by further quantum layers or by classical layers.

# %% [markdown]
# ## Importing basic libraries

# %%
# %pip install pennylane
# Out:
# Collecting pennylane
#   Obtaining dependency information for pennylane from https://files.pythonhosted.org/packages/67/9a/53506ded2d949c95971b73ecc30b6b877db6263f20939998bacc2f738e61/PennyLane-0.31.1-py3-none-any.whl.metadata
#   Downloading PennyLane-0.31.1-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: numpy<1.24 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from pennylane) (1.23.5)
# Requirement already satisfied: scipy in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from pennylane) (1.8.0)
# Collecting networkx (from pennylane)
#   Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Requirement already satisfied: rustworkx in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from pennylane) (0.13.1)
# Collecting autograd<=1.5 (from pennylane)
#   Downloading autograd-1.5-py3-none-any.whl (48 kB)
#      -------------------------------------- 48.9/48.9 kB 823.6 kB/s eta 0:00:00
# Requirement already satisfied: toml in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from pennylane) (0.10.2)
# Requirement already satisfied: appdirs in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from pennylane) (1.4.4)
# Collecting semantic-version>=2.7 (from pennylane)
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting autoray<=0.6.3,>=0.3.1 (from pennylane)
#   Downloading autoray-0.6.3-py3-none-any.whl (48 kB)
#      ---------------------------------------- 48.3/48.3 kB ? eta 0:00:00
# Requirement already satisfied: cachetools in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from pennylane) (5.2.0)
# Collecting pennylane-lightning>=0.31 (from pennylane)
#   Obtaining dependency information for pennylane-lightning>=0.31 from https://files.pythonhosted.org/packages/33/9e/e34421ea42d36d6f6a409660727eabfe5dc06bcbe43d0878b2709cf6bfd5/PennyLane_Lightning-0.31.0-cp310-cp310-win_amd64.whl.metadata
#   Downloading PennyLane_Lightning-0.31.0-cp310-cp310-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: requests in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from pennylane) (2.28.1)
# Requirement already satisfied: typing-extensions in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from pennylane) (4.5.0)
# Requirement already satisfied: future>=0.15.2 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from autograd<=1.5->pennylane) (0.18.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from requests->pennylane) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from requests->pennylane) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from requests->pennylane) (1.26.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\appdata\roaming\python\python310\site-packages (from requests->pennylane) (2022.6.15)
# Downloading PennyLane-0.31.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 1.5/1.5 MB 5.8 MB/s eta 0:00:00
# Downloading PennyLane_Lightning-0.31.0-cp310-cp310-win_amd64.whl (4.6 MB)
#    ---------------------------------------- 4.6/4.6 MB 7.5 MB/s eta 0:00:00
# Installing collected packages: semantic-version, networkx, autoray, autograd, pennylane-lightning, pennylane
# Successfully installed autograd-1.5 autoray-0.6.3 networkx-3.1 pennylane-0.31.1 pennylane-lightning-0.31.0 semantic-version-2.10.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\appdata\local\programs\python\python310\lib\site-packages)
#   WARNING: The script pl-device-test.exe is installed in 'c:\Users\Dell\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers

import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# %% [markdown]
# ### Setting the main hyper-parameters

# %%
n_epochs = 40     # number of epochs to run
n_layers = 1      # number of random layers
n_train = 50      # size of training dataset
n_test = 30       # size of test dataset



SAVE_PATH = 'qcnn/'   # where to save
PREPROCESS = True    # if false, skip quantum processing and load data from saved path

np.random.seed(135)
tf.random.set_seed(135)

# %% [markdown]
# ### Load the dataset
# We will work with the MNIST dataset, which is already available in tensorflow.

# %%
# mnist_dataset = keras.datasets.mnist
# (train_images, train_labels), (test_images, test_labels) = mnist_dataset.load_data()

# %%
# train_images.shape

# %%
import pandas as pd

# %%
train_dataset = pd.read_csv('data/label/training.csv')

#keep only fisrst two columns
train_dataset = train_dataset.iloc[:, :2]

train_dataset.head()
# Out:
#   Image name  Retinopathy grade
# 0  IDRiD_001                  3
# 1  IDRiD_002                  3
# 2  IDRiD_003                  2
# 3  IDRiD_004                  3
# 4  IDRiD_005                  4

# %%
# shuffle the dataset 

train_dataset = train_dataset.sample(frac=1).reset_index(drop=True)

train_dataset
# Out:
#     Image name  Retinopathy grade
# 0    IDRiD_295                  0
# 1    IDRiD_199                  0
# 2    IDRiD_327                  3
# 3    IDRiD_196                  2
# 4    IDRiD_072                  2
# ..         ...                ...
# 408  IDRiD_388                  1
# 409  IDRiD_364                  3
# 410  IDRiD_298                  0
# 411  IDRiD_409                  2
# 412  IDRiD_329                  3
#
# [413 rows x 2 columns]

# %%
PATH = 'data/images/filtered_train_images/'

file_paths = []
labels = []

for i in range(0,len(train_dataset)):
    file_paths.append(PATH + train_dataset['Image name'][i] + '.jpg')
    labels.append(train_dataset["Retinopathy grade"][i])
    
path_series = pd.Series(file_paths, name='Image name')
label_series = pd.Series(labels, name='Retinopathy grade')    
training_data = pd.concat([path_series, label_series], axis=1)
training_data.head()
# Out:
#                                         Image name  Retinopathy grade
# 0  data/images/filtered_train_images/IDRiD_295.jpg                  0
# 1  data/images/filtered_train_images/IDRiD_199.jpg                  0
# 2  data/images/filtered_train_images/IDRiD_327.jpg                  3
# 3  data/images/filtered_train_images/IDRiD_196.jpg                  2
# 4  data/images/filtered_train_images/IDRiD_072.jpg                  2

# %%
mask = np.random.rand(len(training_data)) < 0.8
train = training_data[mask]
test = training_data[~mask]

print('Training Data Size :- ',train.shape)
print('Testing Data Size :- ',test.shape)
# Out:
# Training Data Size :-  (336, 2)
# Testing Data Size :-  (77, 2)

# %%
x = train['Image name']
y = train['Retinopathy grade']

# %%
x
# Out:
# 0      data/images/filtered_train_images/IDRiD_295.jpg
# 3      data/images/filtered_train_images/IDRiD_196.jpg
# 4      data/images/filtered_train_images/IDRiD_072.jpg
# 5      data/images/filtered_train_images/IDRiD_156.jpg
# 6      data/images/filtered_train_images/IDRiD_035.jpg
#                             ...
# 408    data/images/filtered_train_images/IDRiD_388.jpg
# 409    data/images/filtered_train_images/IDRiD_364.jpg
# 410    data/images/filtered_train_images/IDRiD_298.jpg
# 411    data/images/filtered_train_images/IDRiD_409.jpg
# 412    data/images/filtered_train_images/IDRiD_329.jpg
# Name: Image name, Length: 336, dtype: object

# %%
import cv2
import numpy as np

# %%
train_imgs = []

for path in x :

    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (224, 224))
    img = np.array(img)
    train_imgs.append(img)

# %%
# make a tensor of (len(train_imags), 28, 28, 1) and store train_imgs in it

train_images = np.zeros((len(train_imgs), 224, 224, 1))
for i in range(len(train_imgs)):
    train_images[i] = train_imgs[i].reshape(224, 224, 1)

# %%
train_images.shape
# Out:
# (336, 224, 224, 1)

# %%
xt = test['Image name']
yt = test['Retinopathy grade']

# %%
xt
# Out:
# 1      data/images/filtered_train_images/IDRiD_199.jpg
# 2      data/images/filtered_train_images/IDRiD_327.jpg
# 11     data/images/filtered_train_images/IDRiD_390.jpg
# 19     data/images/filtered_train_images/IDRiD_130.jpg
# 26     data/images/filtered_train_images/IDRiD_209.jpg
#                             ...
# 369    data/images/filtered_train_images/IDRiD_336.jpg
# 374    data/images/filtered_train_images/IDRiD_358.jpg
# 391    data/images/filtered_train_images/IDRiD_014.jpg
# 394    data/images/filtered_train_images/IDRiD_144.jpg
# 402    data/images/filtered_train_images/IDRiD_095.jpg
# Name: Image name, Length: 77, dtype: object

# %%
test_imgs = []

for path in xt :

    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (224, 224))
    img = np.array(img)
    test_imgs.append(img)

# %%
# make a tensor of (len(test_imags), 28, 28, 1) and store test_imgs in it

test_images = np.zeros((len(test_imgs), 224, 224, 1))
for i in range(len(test_imgs)):
    test_images[i] = test_imgs[i].reshape(224, 224, 1)

# %%
test_images.shape
# Out:
# (77, 224, 224, 1)

# %% [markdown]
# We will only be working with a small subset of the entire problem

# %%
# train_images = train_images[:n_train]
train_labels = y

# for the test data
# test_images = test_images[:n_test]
test_labels = yt

# %% [markdown]
# ## Normalizing the data

# %%
train_images = train_images / 255
test_images = test_images / 255

# %%
test_images.shape
# Out:
# (77, 224, 224, 1)

# %% [markdown]
# #### Adding an extra dimension for the convolutional channels

# %%
train_images = np.array(train_images[..., tf.newaxis])

test_images = np.array(test_images[..., tf.newaxis])

# %%
train_images.shape
# Out:
# (336, 224, 224, 1, 1)

# %% [markdown]
# ### Quantum Circuit as a convolution kernel

# %% [markdown]
# We follow the scheme  described below. We initialize the Pennylane ```default.qubit``` device, simulating a system of 4 Qubits.
# The associated ```qnode```  represents the quantum circuit consisiting of:
#
#
#
# 1.   an embedding layer of local $R_y$ rotations (with angles scaled by a factor of $\pi$)
# 2.   a random circuit of ```n_layers```
# 3. a final measurement in the computational basis, estimating $4$ expectation values.

# %%
dev = qml.device('default.qubit', wires=4)

# now the random circuit

rand_params = np.random.uniform(high=2*np.pi, size = (n_layers,4))

@qml.qnode(dev)
def circuit(phi):
  # encoding of 4 classical input
  for j in range(4):
    qml.RY(np.pi *phi[j], wires = j)

  # random circuit

  RandomLayers(rand_params, wires = list(range(4)))

  # Measurement
  return [qml.expval(qml.PauliZ(j)) for j in range(4)]

# %% [markdown]
# ### The convolutional Scheme
#
#
#
# 1.   the image is divided into squares of $2 \times 2$ pixels
# 2.   each square is processed by the quantum circuit
# 3. the $4$ expectation values are mapped into $4$ different channels of a single output pixel

# %%
def quanv(image):
    """Convolves the input image with many applications of the same quantum circuit."""
    out = np.zeros((112, 112, 4))

    # Loop over the coordinates of the top-left pixel of 2X2 squares
    for j in range(0, 224, 2):
        for k in range(0, 224, 2):
            # Process a squared 2x2 region of the image with a quantum circuit
            q_results = circuit(
                [
                    image[j, k, 0],
                    image[j, k + 1, 0],
                    image[j + 1, k, 0],
                    image[j + 1, k + 1, 0]
                ]
            )
            # Assign expectation values to different channels of the output pixel (j/2, k/2)
            for c in range(4):
                out[j // 2, k // 2, c] = q_results[c]
    return out

# %% [markdown]
# ### Quantum Preprocessing
#
# Since we are not going to train the quantum convolution layer, it is more efficient to apply it as a “pre-processing” layer to all the images of our dataset. Later an entirely classical model will be directly trained and tested on the pre-processed dataset, avoiding unnecessary repetitions of quantum computations.
#
# The pre-processed images will be saved in the folder SAVE_PATH. Once saved, they can be directly loaded by setting PREPROCESS = False, otherwise the quantum convolution is evaluated at each run of the code.

# %%
train_images.shape
# Out:
# (336, 224, 224, 1, 1)

# %%
if PREPROCESS == True:
    q_train_images = []
    print("Quantum pre-processing of train images:")
    for idx, img in enumerate(train_images):
        print("{}/{}        ".format(idx + 1, len(train_images)), end="\r")
        q_train_images.append(quanv(img))
    q_train_images = np.asarray(q_train_images)

    q_test_images = []
    print("\nQuantum pre-processing of test images:")
    for idx, img in enumerate(test_images):
        print("{}/{}        ".format(idx + 1, len(test_images)), end="\r")
        q_test_images.append(quanv(img))
    q_test_images = np.asarray(q_test_images)

    # Save pre-processed images
    np.save( "q_train_images.npy", q_train_images)
    np.save( "q_test_images.npy", q_test_images)


# Load pre-processed images
q_train_images = np.load( "q_train_images.npy")
q_test_images = np.load( "q_test_images.npy")
# Out:
# Quantum pre-processing of train images:
# 336/336
# Quantum pre-processing of test images:
# 77/77

# %% [markdown]
# ### Visualize

# %%
n_samples = 4
n_channels = 4
fig, axes = plt.subplots(1 + n_channels, n_samples, figsize=(10, 10))
for k in range(n_samples):
    axes[0, 0].set_ylabel("Input")
    if k != 0:
        axes[0, k].yaxis.set_visible(False)
    axes[0, k].imshow(train_images[k, :, :, 0], cmap="gray")

    # Plot all output channels
    for c in range(n_channels):
        axes[c + 1, 0].set_ylabel("Output [ch. {}]".format(c))
        if k != 0:
            axes[c, k].yaxis.set_visible(False)
        axes[c + 1, k].imshow(q_train_images[k, :, :, c], cmap="gray")

plt.tight_layout()
plt.show()

# %% [markdown]
# Below each input image, the
# 4
#  output channels generated by the quantum convolution are visualized in gray scale.
#
# One can clearly notice the downsampling of the resolution and some local distortion introduced by the quantum kernel. On the other hand the global shape of the image is preserved, as expected for a convolution layer.

# %% [markdown]
# ### Hybrid quantum-classical model
# After the application of the quantum convolution layer we feed the resulting features into a classical neural network that will be trained to classify the
# 10
#  different digits of the MNIST dataset.
#
# We use a very simple model: just a fully connected layer with 10 output nodes with a final softmax activation function.
#
# The model is compiled with a stochastic-gradient-descent optimizer, and a cross-entropy loss function.

# %%
def MyModel():
    """Initializes and returns a custom Keras model
    which is ready to be trained."""
    model = keras.models.Sequential([
        keras.layers.Flatten(),
        keras.layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer='adam',
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model

# %% [markdown]
# ### Training
#
# We first initialize an instance of the model, then we train and validate it with the dataset that has been already pre-processed by a quantum convolution

# %%
q_model = MyModel()

q_history = q_model.fit(
    q_train_images,
    train_labels,
    validation_data=(q_test_images, test_labels),
    batch_size=16,
    epochs=2*n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/80
# 21/21 - 1s - loss: 7.6822 - accuracy: 0.2619 - val_loss: 5.5405 - val_accuracy: 0.2987 - 1s/epoch - 66ms/step
# Epoch 2/80
# 21/21 - 0s - loss: 2.1564 - accuracy: 0.5714 - val_loss: 2.5670 - val_accuracy: 0.1818 - 171ms/epoch - 8ms/step
# Epoch 3/80
# 21/21 - 0s - loss: 0.3465 - accuracy: 0.8601 - val_loss: 2.0890 - val_accuracy: 0.3636 - 157ms/epoch - 7ms/step
# Epoch 4/80
# 21/21 - 0s - loss: 0.0894 - accuracy: 0.9821 - val_loss: 1.4981 - val_accuracy: 0.3896 - 272ms/epoch - 13ms/step
# Epoch 5/80
# 21/21 - 0s - loss: 0.0707 - accuracy: 0.9940 - val_loss: 1.7126 - val_accuracy: 0.4026 - 219ms/epoch - 10ms/step
# Epoch 6/80
# 21/21 - 0s - loss: 0.0523 - accuracy: 0.9970 - val_loss: 1.7492 - val_accuracy: 0.4286 - 230ms/epoch - 11ms/step
# Epoch 7/80
# 21/21 - 0s - loss: 0.0634 - accuracy: 0.9940 - val_loss: 2.6828 - val_accuracy: 0.2987 - 179ms/epoch - 9ms/step
# Epoch 8/80
# 21/21 - 0s - loss: 0.0648 - accuracy: 0.9911 - val_loss: 2.2686 - val_accuracy: 0.3636 - 182ms/epoch - 9ms/step
# Epoch 9/80
# 21/21 - 0s - loss: 0.0799 - accuracy: 0.9911 - val_loss: 2.6376 - val_accuracy: 0.3247 - 185ms/epoch - 9ms/step
# Epoch 10/80
# 21/21 - 0s - loss: 0.0184 - accuracy: 0.9970 - val_loss: 2.4115 - val_accuracy: 0.3377 - 176ms/epoch - 8ms/step
# Epoch 11/80
# 21/21 - 0s - loss: 0.0365 - accuracy: 0.9911 - val_loss: 2.3285 - val_accuracy: 0.2727 - 179ms/epoch - 9ms/step
# Epoch 12/80
# 21/21 - 0s - loss: 0.0297 - accuracy: 0.9940 - val_loss: 2.8094 - val_accuracy: 0.3117 - 179ms/epoch - 9ms/step
# Epoch 13/80
# 21/21 - 0s - loss: 0.0830 - accuracy: 0.9940 - val_loss: 2.6792 - val_accuracy: 0.3377 - 162ms/epoch - 8ms/step
# Epoch 14/80
# 21/21 - 0s - loss: 0.0508 - accuracy: 0.9970 - val_loss: 2.5047 - val_accuracy: 0.1558 - 169ms/epoch - 8ms/step
# Epoch 15/80
# 21/21 - 0s - loss: 0.0928 - accuracy: 0.9940 - val_loss: 1.8524 - val_accuracy: 0.3636 - 169ms/epoch - 8ms/step
# Epoch 16/80
# 21/21 - 0s - loss: 0.0421 - accuracy: 0.9970 - val_loss: 2.6917 - val_accuracy: 0.3506 - 161ms/epoch - 8ms/step
# Epoch 17/80
# 21/21 - 0s - loss: 0.0600 - accuracy: 0.9970 - val_loss: 2.4009 - val_accuracy: 0.3247 - 232ms/epoch - 11ms/step
# Epoch 18/80
# 21/21 - 0s - loss: 0.0139 - accuracy: 0.9970 - val_loss: 3.0476 - val_accuracy: 0.3247 - 195ms/epoch - 9ms/step
# Epoch 19/80
# 21/21 - 0s - loss: 0.0518 - accuracy: 0.9940 - val_loss: 1.7243 - val_accuracy: 0.3896 - 188ms/epoch - 9ms/step
# Epoch 20/80
# 21/21 - 0s - loss: 0.0323 - accuracy: 0.9970 - val_loss: 3.0808 - val_accuracy: 0.3506 - 213ms/epoch - 10ms/step
# Epoch 21/80
# 21/21 - 0s - loss: 0.0437 - accuracy: 0.9911 - val_loss: 3.5607 - val_accuracy: 0.2468 - 186ms/epoch - 9ms/step
# Epoch 22/80
# 21/21 - 0s - loss: 0.0587 - accuracy: 0.9940 - val_loss: 1.8777 - val_accuracy: 0.4286 - 186ms/epoch - 9ms/step
# Epoch 23/80
# 21/21 - 0s - loss: 0.0599 - accuracy: 0.9970 - val_loss: 2.7131 - val_accuracy: 0.3117 - 183ms/epoch - 9ms/step
# Epoch 24/80
# 21/21 - 0s - loss: 0.0415 - accuracy: 0.9970 - val_loss: 1.6516 - val_accuracy: 0.4545 - 193ms/epoch - 9ms/step
# Epoch 25/80
# 21/21 - 0s - loss: 0.0542 - accuracy: 0.9970 - val_loss: 2.3730 - val_accuracy: 0.4026 - 179ms/epoch - 9ms/step
# Epoch 26/80
# 21/21 - 0s - loss: 0.0326 - accuracy: 0.9970 - val_loss: 1.6100 - val_accuracy: 0.4026 - 175ms/epoch - 8ms/step
# Epoch 27/80
# 21/21 - 0s - loss: 0.0851 - accuracy: 0.9911 - val_loss: 2.2583 - val_accuracy: 0.4286 - 187ms/epoch - 9ms/step
# Epoch 28/80
# 21/21 - 0s - loss: 0.0559 - accuracy: 0.9940 - val_loss: 2.2974 - val_accuracy: 0.4545 - 208ms/epoch - 10ms/step
# Epoch 29/80
# 21/21 - 0s - loss: 0.0573 - accuracy: 0.9970 - val_loss: 3.7282 - val_accuracy: 0.2597 - 242ms/epoch - 12ms/step
# Epoch 30/80
# 21/21 - 0s - loss: 0.0646 - accuracy: 0.9940 - val_loss: 3.3922 - val_accuracy: 0.2597 - 232ms/epoch - 11ms/step
# Epoch 31/80
# 21/21 - 0s - loss: 0.0475 - accuracy: 0.9970 - val_loss: 2.0756 - val_accuracy: 0.4156 - 234ms/epoch - 11ms/step
# Epoch 32/80
# 21/21 - 0s - loss: 0.0529 - accuracy: 0.9940 - val_loss: 2.1030 - val_accuracy: 0.3377 - 231ms/epoch - 11ms/step
# Epoch 33/80
# 21/21 - 0s - loss: 0.0462 - accuracy: 0.9970 - val_loss: 4.7471 - val_accuracy: 0.2468 - 223ms/epoch - 11ms/step
# Epoch 34/80
# 21/21 - 0s - loss: 0.0868 - accuracy: 0.9940 - val_loss: 5.0310 - val_accuracy: 0.2468 - 190ms/epoch - 9ms/step
# Epoch 35/80
# 21/21 - 0s - loss: 0.0832 - accuracy: 0.9940 - val_loss: 3.2846 - val_accuracy: 0.3766 - 227ms/epoch - 11ms/step
# Epoch 36/80
# 21/21 - 0s - loss: 0.0752 - accuracy: 0.9940 - val_loss: 3.4363 - val_accuracy: 0.2597 - 225ms/epoch - 11ms/step
# Epoch 37/80
# 21/21 - 0s - loss: 0.0525 - accuracy: 0.9970 - val_loss: 1.7060 - val_accuracy: 0.3247 - 199ms/epoch - 9ms/step
# Epoch 38/80
# 21/21 - 0s - loss: 0.1099 - accuracy: 0.9940 - val_loss: 2.6971 - val_accuracy: 0.4026 - 203ms/epoch - 10ms/step
# Epoch 39/80
# 21/21 - 0s - loss: 0.0350 - accuracy: 0.9970 - val_loss: 4.0220 - val_accuracy: 0.2597 - 266ms/epoch - 13ms/step
# Epoch 40/80
# 21/21 - 0s - loss: 0.0532 - accuracy: 0.9940 - val_loss: 4.5358 - val_accuracy: 0.2597 - 204ms/epoch - 10ms/step
# Epoch 41/80
# 21/21 - 0s - loss: 0.0749 - accuracy: 0.9940 - val_loss: 4.9694 - val_accuracy: 0.2468 - 220ms/epoch - 10ms/step
# Epoch 42/80
# 21/21 - 0s - loss: 0.0378 - accuracy: 0.9970 - val_loss: 2.4049 - val_accuracy: 0.4545 - 182ms/epoch - 9ms/step
# Epoch 43/80
# 21/21 - 0s - loss: 0.1031 - accuracy: 0.9911 - val_loss: 3.1526 - val_accuracy: 0.1429 - 193ms/epoch - 9ms/step
# Epoch 44/80
# 21/21 - 0s - loss: 0.0383 - accuracy: 0.9970 - val_loss: 3.5927 - val_accuracy: 0.3506 - 205ms/epoch - 10ms/step
# Epoch 45/80
# 21/21 - 0s - loss: 0.0799 - accuracy: 0.9911 - val_loss: 2.0575 - val_accuracy: 0.3896 - 220ms/epoch - 10ms/step
# Epoch 46/80
# 21/21 - 0s - loss: 0.0230 - accuracy: 0.9940 - val_loss: 2.6698 - val_accuracy: 0.2468 - 213ms/epoch - 10ms/step
# Epoch 47/80
# 21/21 - 0s - loss: 0.0568 - accuracy: 0.9970 - val_loss: 2.2252 - val_accuracy: 0.3636 - 207ms/epoch - 10ms/step
# Epoch 48/80
# 21/21 - 0s - loss: 0.0378 - accuracy: 0.9940 - val_loss: 3.4251 - val_accuracy: 0.2727 - 222ms/epoch - 11ms/step
# Epoch 49/80
# 21/21 - 0s - loss: 0.0803 - accuracy: 0.9940 - val_loss: 5.6342 - val_accuracy: 0.2468 - 217ms/epoch - 10ms/step
# Epoch 50/80
# 21/21 - 0s - loss: 0.0690 - accuracy: 0.9940 - val_loss: 3.5177 - val_accuracy: 0.4286 - 209ms/epoch - 10ms/step
# Epoch 51/80
# 21/21 - 0s - loss: 0.0378 - accuracy: 0.9970 - val_loss: 2.6363 - val_accuracy: 0.3117 - 206ms/epoch - 10ms/step
# Epoch 52/80
# 21/21 - 0s - loss: 0.0271 - accuracy: 0.9970 - val_loss: 3.2639 - val_accuracy: 0.4156 - 233ms/epoch - 11ms/step
# Epoch 53/80
# 21/21 - 0s - loss: 0.0462 - accuracy: 0.9881 - val_loss: 4.0166 - val_accuracy: 0.2727 - 244ms/epoch - 12ms/step
# Epoch 54/80
# 21/21 - 0s - loss: 0.0277 - accuracy: 0.9970 - val_loss: 1.8209 - val_accuracy: 0.4416 - 233ms/epoch - 11ms/step
# Epoch 55/80
# 21/21 - 0s - loss: 0.0246 - accuracy: 0.9970 - val_loss: 3.2727 - val_accuracy: 0.3636 - 214ms/epoch - 10ms/step
# Epoch 56/80
# 21/21 - 0s - loss: 0.0399 - accuracy: 0.9881 - val_loss: 2.3664 - val_accuracy: 0.2338 - 190ms/epoch - 9ms/step
# Epoch 57/80
# 21/21 - 0s - loss: 0.1747 - accuracy: 0.9851 - val_loss: 2.5025 - val_accuracy: 0.4026 - 174ms/epoch - 8ms/step
# Epoch 58/80
# 21/21 - 0s - loss: 0.0539 - accuracy: 0.9970 - val_loss: 2.2043 - val_accuracy: 0.4416 - 216ms/epoch - 10ms/step
# Epoch 59/80
# 21/21 - 0s - loss: 0.0399 - accuracy: 0.9970 - val_loss: 3.0533 - val_accuracy: 0.3766 - 212ms/epoch - 10ms/step
# Epoch 60/80
# 21/21 - 0s - loss: 0.0588 - accuracy: 0.9940 - val_loss: 3.9292 - val_accuracy: 0.3377 - 182ms/epoch - 9ms/step
# Epoch 61/80
# 21/21 - 0s - loss: 0.0665 - accuracy: 0.9940 - val_loss: 2.5646 - val_accuracy: 0.4026 - 167ms/epoch - 8ms/step
# Epoch 62/80
# 21/21 - 0s - loss: 0.0786 - accuracy: 0.9911 - val_loss: 4.0893 - val_accuracy: 0.2987 - 187ms/epoch - 9ms/step
# Epoch 63/80
# 21/21 - 0s - loss: 0.0441 - accuracy: 0.9970 - val_loss: 2.8314 - val_accuracy: 0.4416 - 171ms/epoch - 8ms/step
# Epoch 64/80
# 21/21 - 0s - loss: 0.0557 - accuracy: 0.9970 - val_loss: 2.7953 - val_accuracy: 0.2208 - 176ms/epoch - 8ms/step
# Epoch 65/80
# 21/21 - 0s - loss: 0.0496 - accuracy: 0.9970 - val_loss: 5.3223 - val_accuracy: 0.2468 - 176ms/epoch - 8ms/step
# Epoch 66/80
# 21/21 - 0s - loss: 0.0937 - accuracy: 0.9970 - val_loss: 2.9111 - val_accuracy: 0.4156 - 170ms/epoch - 8ms/step
# Epoch 67/80
# 21/21 - 0s - loss: 0.0646 - accuracy: 0.9970 - val_loss: 5.2858 - val_accuracy: 0.2597 - 177ms/epoch - 8ms/step
# Epoch 68/80
# 21/21 - 0s - loss: 0.0914 - accuracy: 0.9970 - val_loss: 3.3672 - val_accuracy: 0.3377 - 184ms/epoch - 9ms/step
# Epoch 69/80
# 21/21 - 0s - loss: 0.0559 - accuracy: 0.9940 - val_loss: 4.6919 - val_accuracy: 0.2468 - 183ms/epoch - 9ms/step
# Epoch 70/80
# 21/21 - 0s - loss: 0.0268 - accuracy: 0.9970 - val_loss: 6.9091 - val_accuracy: 0.2468 - 178ms/epoch - 8ms/step
# Epoch 71/80
# 21/21 - 0s - loss: 0.1165 - accuracy: 0.9970 - val_loss: 3.3807 - val_accuracy: 0.4286 - 182ms/epoch - 9ms/step
# Epoch 72/80
# 21/21 - 0s - loss: 0.1649 - accuracy: 0.9732 - val_loss: 3.4019 - val_accuracy: 0.3766 - 159ms/epoch - 8ms/step
# Epoch 73/80
# 21/21 - 0s - loss: 0.1231 - accuracy: 0.9643 - val_loss: 3.5801 - val_accuracy: 0.2597 - 165ms/epoch - 8ms/step
# Epoch 74/80
# 21/21 - 0s - loss: 0.0904 - accuracy: 0.9970 - val_loss: 5.6049 - val_accuracy: 0.2727 - 233ms/epoch - 11ms/step
# Epoch 75/80
# 21/21 - 0s - loss: 0.0578 - accuracy: 0.9940 - val_loss: 3.2337 - val_accuracy: 0.3636 - 179ms/epoch - 9ms/step
# Epoch 76/80
# 21/21 - 0s - loss: 0.0566 - accuracy: 0.9940 - val_loss: 7.3949 - val_accuracy: 0.2468 - 171ms/epoch - 8ms/step
# Epoch 77/80
# 21/21 - 0s - loss: 0.1902 - accuracy: 0.9821 - val_loss: 4.1072 - val_accuracy: 0.3247 - 188ms/epoch - 9ms/step
# Epoch 78/80
# 21/21 - 0s - loss: 0.1414 - accuracy: 0.9940 - val_loss: 5.0435 - val_accuracy: 0.2857 - 167ms/epoch - 8ms/step
# Epoch 79/80
# 21/21 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 3.7190 - val_accuracy: 0.4156 - 183ms/epoch - 9ms/step
# Epoch 80/80
# 21/21 - 0s - loss: 0.1501 - accuracy: 0.9940 - val_loss: 3.5872 - val_accuracy: 0.4416 - 160ms/epoch - 8ms/step

# %% [markdown]
# In order to compare the results achievable with and without the quantum convolution layer, we initialize also a “classical” instance of the model that will be directly trained and validated with the raw MNIST images (i.e., without quantum pre-processing).

# %%
c_model = MyModel()

c_history = c_model.fit(
    train_images,
    train_labels,
    validation_data=(test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/40
# 84/84 - 1s - loss: 12.8850 - accuracy: 0.2143 - val_loss: 10.7103 - val_accuracy: 0.2078 - 1s/epoch - 14ms/step
# Epoch 2/40
# 84/84 - 0s - loss: 8.8117 - accuracy: 0.2738 - val_loss: 6.4754 - val_accuracy: 0.1688 - 463ms/epoch - 6ms/step
# Epoch 3/40
# 84/84 - 0s - loss: 6.4666 - accuracy: 0.3125 - val_loss: 3.8433 - val_accuracy: 0.2078 - 467ms/epoch - 6ms/step
# Epoch 4/40
# 84/84 - 0s - loss: 6.0717 - accuracy: 0.3185 - val_loss: 5.7554 - val_accuracy: 0.2468 - 424ms/epoch - 5ms/step
# Epoch 5/40
# 84/84 - 1s - loss: 5.9715 - accuracy: 0.3929 - val_loss: 8.1474 - val_accuracy: 0.3506 - 501ms/epoch - 6ms/step
# Epoch 6/40
# 84/84 - 0s - loss: 7.0065 - accuracy: 0.3958 - val_loss: 5.5073 - val_accuracy: 0.3766 - 418ms/epoch - 5ms/step
# Epoch 7/40
# 84/84 - 0s - loss: 5.9228 - accuracy: 0.4226 - val_loss: 6.4649 - val_accuracy: 0.3636 - 370ms/epoch - 4ms/step
# Epoch 8/40
# 84/84 - 0s - loss: 6.8302 - accuracy: 0.4196 - val_loss: 5.5574 - val_accuracy: 0.2857 - 388ms/epoch - 5ms/step
# Epoch 9/40
# 84/84 - 0s - loss: 5.1917 - accuracy: 0.4524 - val_loss: 5.8941 - val_accuracy: 0.2597 - 398ms/epoch - 5ms/step
# Epoch 10/40
# 84/84 - 0s - loss: 5.1518 - accuracy: 0.4167 - val_loss: 7.5522 - val_accuracy: 0.3377 - 460ms/epoch - 5ms/step
# Epoch 11/40
# 84/84 - 0s - loss: 7.9895 - accuracy: 0.3839 - val_loss: 7.8506 - val_accuracy: 0.3506 - 456ms/epoch - 5ms/step
# Epoch 12/40
# 84/84 - 0s - loss: 8.4029 - accuracy: 0.3750 - val_loss: 10.0940 - val_accuracy: 0.2468 - 381ms/epoch - 5ms/step
# Epoch 13/40
# 84/84 - 0s - loss: 6.0799 - accuracy: 0.3988 - val_loss: 9.9692 - val_accuracy: 0.1429 - 385ms/epoch - 5ms/step
# Epoch 14/40
# 84/84 - 0s - loss: 5.9135 - accuracy: 0.3810 - val_loss: 7.7366 - val_accuracy: 0.4156 - 460ms/epoch - 5ms/step
# Epoch 15/40
# 84/84 - 1s - loss: 5.7692 - accuracy: 0.4732 - val_loss: 3.5951 - val_accuracy: 0.4026 - 561ms/epoch - 7ms/step
# Epoch 16/40
# 84/84 - 0s - loss: 5.2020 - accuracy: 0.4554 - val_loss: 2.4974 - val_accuracy: 0.4416 - 467ms/epoch - 6ms/step
# Epoch 17/40
# 84/84 - 0s - loss: 3.2702 - accuracy: 0.5595 - val_loss: 8.2947 - val_accuracy: 0.2468 - 485ms/epoch - 6ms/step
# Epoch 18/40
# 84/84 - 0s - loss: 4.4014 - accuracy: 0.4286 - val_loss: 5.7770 - val_accuracy: 0.4156 - 460ms/epoch - 5ms/step
# Epoch 19/40
# 84/84 - 0s - loss: 3.1061 - accuracy: 0.5774 - val_loss: 6.5096 - val_accuracy: 0.3506 - 495ms/epoch - 6ms/step
# Epoch 20/40
# 84/84 - 1s - loss: 3.0066 - accuracy: 0.5655 - val_loss: 5.1854 - val_accuracy: 0.3377 - 517ms/epoch - 6ms/step
# Epoch 21/40
# 84/84 - 0s - loss: 3.3345 - accuracy: 0.5565 - val_loss: 4.9587 - val_accuracy: 0.2857 - 457ms/epoch - 5ms/step
# Epoch 22/40
# 84/84 - 1s - loss: 2.8138 - accuracy: 0.5893 - val_loss: 3.8711 - val_accuracy: 0.3247 - 533ms/epoch - 6ms/step
# Epoch 23/40
# 84/84 - 0s - loss: 1.9865 - accuracy: 0.6369 - val_loss: 5.8934 - val_accuracy: 0.2468 - 431ms/epoch - 5ms/step
# Epoch 24/40
# 84/84 - 0s - loss: 2.3340 - accuracy: 0.6190 - val_loss: 4.3749 - val_accuracy: 0.1948 - 450ms/epoch - 5ms/step
# Epoch 25/40
# 84/84 - 0s - loss: 4.2655 - accuracy: 0.4464 - val_loss: 2.8732 - val_accuracy: 0.4026 - 450ms/epoch - 5ms/step
# Epoch 26/40
# 84/84 - 0s - loss: 3.0219 - accuracy: 0.6161 - val_loss: 4.2100 - val_accuracy: 0.2597 - 462ms/epoch - 5ms/step
# Epoch 27/40
# 84/84 - 1s - loss: 4.0680 - accuracy: 0.5357 - val_loss: 3.6830 - val_accuracy: 0.3896 - 587ms/epoch - 7ms/step
# Epoch 28/40
# 84/84 - 0s - loss: 3.9928 - accuracy: 0.5417 - val_loss: 6.0426 - val_accuracy: 0.2468 - 491ms/epoch - 6ms/step
# Epoch 29/40
# 84/84 - 0s - loss: 3.9298 - accuracy: 0.6042 - val_loss: 8.2314 - val_accuracy: 0.3247 - 455ms/epoch - 5ms/step
# Epoch 30/40
# 84/84 - 0s - loss: 2.6724 - accuracy: 0.6518 - val_loss: 3.4652 - val_accuracy: 0.2857 - 388ms/epoch - 5ms/step
# Epoch 31/40
# 84/84 - 0s - loss: 5.4975 - accuracy: 0.5625 - val_loss: 10.9374 - val_accuracy: 0.3896 - 346ms/epoch - 4ms/step
# Epoch 32/40
# 84/84 - 1s - loss: 3.3060 - accuracy: 0.6429 - val_loss: 2.2617 - val_accuracy: 0.4286 - 526ms/epoch - 6ms/step
# Epoch 33/40
# 84/84 - 0s - loss: 1.8365 - accuracy: 0.6756 - val_loss: 2.2801 - val_accuracy: 0.3506 - 463ms/epoch - 6ms/step
# Epoch 34/40
# 84/84 - 1s - loss: 1.8184 - accuracy: 0.7262 - val_loss: 4.6793 - val_accuracy: 0.2597 - 512ms/epoch - 6ms/step
# Epoch 35/40
# 84/84 - 1s - loss: 3.6339 - accuracy: 0.5804 - val_loss: 7.7451 - val_accuracy: 0.2727 - 561ms/epoch - 7ms/step
# Epoch 36/40
# 84/84 - 1s - loss: 2.0428 - accuracy: 0.6905 - val_loss: 4.7104 - val_accuracy: 0.3377 - 758ms/epoch - 9ms/step
# Epoch 37/40
# 84/84 - 0s - loss: 3.5437 - accuracy: 0.5804 - val_loss: 15.9061 - val_accuracy: 0.2468 - 492ms/epoch - 6ms/step
# Epoch 38/40
# 84/84 - 0s - loss: 2.6129 - accuracy: 0.6786 - val_loss: 11.2007 - val_accuracy: 0.2468 - 481ms/epoch - 6ms/step
# Epoch 39/40
# 84/84 - 0s - loss: 2.6266 - accuracy: 0.6577 - val_loss: 8.7917 - val_accuracy: 0.2338 - 466ms/epoch - 6ms/step
# Epoch 40/40
# 84/84 - 1s - loss: 7.7189 - accuracy: 0.4970 - val_loss: 4.1087 - val_accuracy: 0.1688 - 518ms/epoch - 6ms/step

# %% [markdown]
# ## Results

# %%
import matplotlib.pyplot as plt

plt.style.use("seaborn")
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 9))

ax1.plot(q_history.history["val_accuracy"], "-ob", label="With quantum layer")
ax1.plot(c_history.history["val_accuracy"], "-og", label="Without quantum layer")
ax1.set_ylabel("Accuracy")
ax1.set_ylim([0, 1])
ax1.set_xlabel("Epoch")
ax1.legend()

ax2.plot(q_history.history["val_loss"], "-ob", label="With quantum layer")
ax2.plot(c_history.history["val_loss"], "-og", label="Without quantum layer")
ax2.set_ylabel("Loss")
ax2.set_ylim(top=2.5)
ax2.set_xlabel("Epoch")
ax2.legend()
plt.tight_layout()
plt.show()
